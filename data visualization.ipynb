# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_df=sns.load_dataset('iris')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
sns.scatterplot(x=iris_df['sepal_length'],y=iris_df['petal_length'])
plt.show()

# %%
sns.scatterplot(x=iris_df['sepal_length'],y=iris_df['petal_length'],hue=iris_df['species'])
plt.show()

# %%
sns.boxplot(x=iris_df['species'],y=iris_df['petal_length'])
plt.show()

# %%
sns.jointplot(x=iris_df['sepal_length'],y=iris_df['sepal_width'])
plt.show()

# %%
sns.jointplot(x=iris_df['sepal_length'],y=iris_df['sepal_width'],kind='reg')
plt.show()

# %%
sns.jointplot(x=iris_df['sepal_length'],y=iris_df['sepal_width'],kind='scatter',color='red')
plt.show()

# %%
sns.jointplot(x=iris_df['sepal_length'],y=iris_df['sepal_width'],kind='kde')
plt.show()

# %%
sns.jointplot(x=iris_df['sepal_length'],y=iris_df['sepal_width'],kind='hex')
plt.show()

# %%
sns.countplot(iris_df['species'],color='green')
# Out:
# C:\Users\botla\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.countplot(y=iris_df['species'],palette=sns.cubehelix_palette(),color='red')
# Out:
# <AxesSubplot:xlabel='count', ylabel='species'>

# %%
sns.distplot(iris_df.petal_length,kde=True)
# Out:
# C:\Users\botla\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.barplot(data=iris_df,x="sepal_length",y="sepal_width",hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
corr=iris_df.corr()
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=iris_df,hue="species",kind="scatter",palette="husl")
